# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_filename = "Production_Crops_E_Asia.csv"

# %%
data = pd.read_csv("Production_Crops_E_Asia.csv")

# %%
data.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y1961', 'Y1961F', 'Y1962',
#        ...
#        'Y2010', 'Y2010F', 'Y2011', 'Y2011F', 'Y2012', 'Y2012F', 'Y2013',
#        'Y2013F', 'Y2014', 'Y2014F'],
#       dtype='object', length=115)

# %%
data.describe()
# Out:
#           Area Code     Item Code  Element Code         Y1961         Y1962  \
# count  10741.000000  10741.000000  10741.000000  6.812000e+03  6.823000e+03
# mean     130.630668    649.406107   5423.645750  5.187470e+05  5.319676e+05
# std       74.057366    585.442493     83.889001  4.265759e+06  4.363923e+06
# min        1.000000     15.000000   5312.000000  0.000000e+00  0.000000e+00
# 25%      100.000000    236.000000   5312.000000  3.000000e+03  3.100000e+03
# 50%      116.000000    430.000000   5419.000000  1.500000e+04  1.500000e+04
# 75%      208.000000    702.000000   5510.000000  8.344100e+04  8.413800e+04
# max      299.000000   1841.000000   5525.000000  1.100010e+08  1.176400e+08
#
#               Y1963         Y1964         Y1965         Y1966         Y1967  \
# count  6.825000e+03  6.843000e+03  6.843000e+03  6.891000e+03  6.919000e+03
# mean   5.381598e+05  5.527095e+05  5.628557e+05  5.747040e+05  5.827793e+05
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data.isnull()
# Out:
#        Area Code   Area  Item Code   Item  Element Code  Element   Unit  \
# 0          False  False      False  False         False    False  False
# 1          False  False      False  False         False    False  False
# 2          False  False      False  False         False    False  False
# 3          False  False      False  False         False    False  False
# 4          False  False      False  False         False    False  False
# 5          False  False      False  False         False    False  False
# 6          False  False      False  False         False    False  False
# 7          False  False      False  False         False    False  False
# 8          False  False      False  False         False    False  False
# 9          False  False      False  False         False    False  False
# 10         False  False      False  False         False    False  False
# 11         False  False      False  False         False    False  False
# ...

# %%
data.isnull().any()
# Out:
# Area Code       False
# Area            False
# Item Code       False
# Item            False
# Element Code    False
# Element         False
# Unit            False
# Y1961            True
# Y1961F           True
# Y1962            True
# Y1962F           True
# Y1963            True
# Y1963F           True
# Y1964            True
# Y1964F           True
# Y1965            True
# Y1965F           True
# Y1966            True
# Y1966F           True
# Y1967            True
# Y1967F           True
# Y1968            True
# Y1968F           True
# Y1969            True
# Y1969F           True
# Y1970            True
# Y1970F           True
# Y1971            True
# Y1971F           True
# Y1972            True
#                 ...
# Y2000            True
# Y2000F           True
# Y2001            True
# Y2001F           True
# Y2002            True
# Y2002F           True
# Y2003            True
# Y2003F           True
# Y2004            True
# Y2004F           True
# ...

# %%
data.isnull().sum()/data.shape[0]
# Out:
# Area Code       0.000000
# Area            0.000000
# Item Code       0.000000
# Item            0.000000
# Element Code    0.000000
# Element         0.000000
# Unit            0.000000
# Y1961           0.365795
# Y1961F          0.446700
# Y1962           0.364771
# Y1962F          0.446048
# Y1963           0.364584
# Y1963F          0.452844
# Y1964           0.362908
# Y1964F          0.455917
# Y1965           0.362908
# Y1965F          0.462992
# Y1966           0.358440
# Y1966F          0.463923
# Y1967           0.355833
# Y1967F          0.461689
# Y1968           0.352574
# Y1968F          0.464575
# Y1969           0.353878
# Y1969F          0.463272
# Y1970           0.353040
# Y1970F          0.470627
# Y1971           0.347454
# Y1971F          0.473792
# Y1972           0.345871
#                   ...
# Y2000           0.068336
# Y2000F          0.320361
# Y2001           0.067126
# Y2001F          0.322968
# Y2002           0.066102
# Y2002F          0.323806
# ...

# %%
data.shape
# Out:
# (10741, 115)

# %%
thresh = len(data)*.6
thresh
# Out:
# 6444.599999999999

# %%
data.dropna(thresh = thresh,axis = 1)
# Out:
#        Area Code         Area  Item Code                              Item  \
# 0              2  Afghanistan        221               Almonds, with shell
# 1              2  Afghanistan        221               Almonds, with shell
# 2              2  Afghanistan        221               Almonds, with shell
# 3              2  Afghanistan        711  Anise, badian, fennel, coriander
# 4              2  Afghanistan        711  Anise, badian, fennel, coriander
# 5              2  Afghanistan        711  Anise, badian, fennel, coriander
# 6              2  Afghanistan        515                            Apples
# 7              2  Afghanistan        515                            Apples
# 8              2  Afghanistan        515                            Apples
# 9              2  Afghanistan        526                          Apricots
# 10             2  Afghanistan        526                          Apricots
# ...

# %%
thresh
# Out:
# 6444.599999999999

# %%
 data.dropna(thresh = 10741, axis = 1).shape
# data.dropna(thresh = 84, axis = 0).shape
# Out:
# (10741, 7)

# %%
data.Y1961.fillna(data.Y1961.median()).isnull().any()
# Out:
# False

# %%
data.Y1961.fillna(data.Y1961.mean()).isnull().any()
# Out:
# False

# %%
data.boxplot("Y1961")
data.hist("Y1961")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017C0001E9B0>]],
#       dtype=object)

# %%
data_outliers = data[ (data.Y1961<data.Y1961.quantile(.9)) & (data.Y1961>data.Y1961.quantile(.1))]

# %%
data_outliers.boxplot("Y1961")
data_outliers.hist("Y1961")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015F9CFAD898>]],
#       dtype=object)

# %%
grouped = data.groupby('Area')

ncols = 1
nrows = int(np.ceil(grouped.ngroups/ncols))

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15,30), sharey=False)

for (key, ax) in zip(grouped.groups.keys(), axes.flatten()):
    grouped.get_group(key)["Y1961"].plot(ax=ax, label=key, legend=True)

ax.legend()
plt.show()

# %%
histt = data[data["Area"]=="Afghanistan"]
histtt = data[data["Item"]=="Apples"]

# %%
s = data.groupby(['Area'])['Y1961'].transform('mean') 
data['Y1961'].fillna(s, inplace=True)
data['Y1961'].fillna(0, inplace=True)

s = data.groupby(['Area'])['Y1962'].transform('mean') 
data['Y1962'].fillna(s, inplace=True)
data['Y1962'].fillna(0, inplace=True)

s = data.groupby(['Area'])['Y1963'].transform('mean') 
data['Y1963'].fillna(s, inplace=True)
data['Y1963'].fillna(0, inplace=True)

s = data.groupby(['Area'])['Y1964'].transform('mean') 
data['Y1964'].fillna(s, inplace=True)
data['Y1964'].fillna(0, inplace=True)

s = data.groupby(['Area'])['Y1965'].transform('mean') 
data['Y1965'].fillna(s, inplace=True)
data['Y1965'].fillna(0, inplace=True)

s = data.groupby(['Area'])['Y1966'].transform('mean') 
data['Y1966'].fillna(s, inplace=True)
data['Y1966'].fillna(0, inplace=True)

s = data.groupby(['Area'])['Y1967'].transform('mean') 
data['Y1967'].fillna(s, inplace=True)
data['Y1967'].fillna(0, inplace=True)

# %%
data["Y1961F"].fillna("Nan", inplace = True)
data["Y1962F"].fillna("Nan", inplace = True)
data["Y1963F"].fillna("Nan", inplace = True)
data["Y1964F"].fillna("Nan", inplace = True)
data["Y1965F"].fillna("Nan", inplace = True)
data["Y1966F"].fillna("Nan", inplace = True)

# %%
grouped = data.groupby('Area')

ncols = 1
nrows = int(np.ceil(grouped.ngroups/ncols))

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15,30), sharey=False)

for (key, ax) in zip(grouped.groups.keys(), axes.flatten()):
    grouped.get_group(key)["Y1961"].plot(ax=ax, label=key, legend=True)

ax.legend()
#plt.ylabel("Year")
plt.show()

# %%
data.to_csv(data_filename.split(".")[0] + "clean.csv")

# %%
s = data.groupby(['Area'])['Y1961'].transform('median') 
data['Y1961'].fillna(s, inplace=True)
Area = data.Area
Y1961 = data.Y1961
plt.plot(s)
plt.xlabel('Area')
plt.ylabel('Y1961')
plt.show()  

s = data.groupby(['Area'])['Y2014'].transform('median') 
data['Y2014'].fillna(s, inplace=True)
Area = data.Area   
Y2014 = data.Y2014
plt.plot(s)
plt.xlabel('Area')
plt.ylabel('Y2014')
plt.show()

# %%
#                           NORMALIZE

df = data[['Area', 'Y1961']]
features_to_normalize = ['Y1961','Y1962','Y1965']

df[features_to_normalize] = data[features_to_normalize].apply(lambda x:(x-x.min()) / (x.max()-x.min())) 
print(df)
# Out:
#               Area     Y1961     Y1962     Y1965
# 0      Afghanistan  0.001798  0.001713  0.001310
# 1      Afghanistan  0.001798  0.001713  0.001310
# 2      Afghanistan  0.001798  0.001713  0.001310
# 3      Afghanistan  0.001798  0.001713  0.001310
# 4      Afghanistan  0.001798  0.001713  0.001310
# 5      Afghanistan  0.001798  0.001713  0.001310
# 6      Afghanistan  0.000020  0.000019  0.000016
# 7      Afghanistan  0.000618  0.000578  0.000517
# 8      Afghanistan  0.000137  0.000128  0.000128
# 9      Afghanistan  0.000044  0.000041  0.000034
# 10     Afghanistan  0.000604  0.000564  0.000508
# 11     Afghanistan  0.000291  0.000272  0.000273
# 12     Afghanistan  0.003182  0.002975  0.002200
# 13     Afghanistan  0.000098  0.000092  0.000068
# 14     Afghanistan  0.003436  0.003213  0.002389
# 15     Afghanistan  0.000255  0.000238  0.000176
# 16     Afghanistan  0.000062  0.000058  0.000043
# 17     Afghanistan  0.000802  0.000750  0.000555
# ...

# %%
import seaborn as sns
color = sns.color_palette()

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

histt = data.Area
cnt_srs = histt.value_counts()
cnt_srs = cnt_srs.head(70)
plt.figure(figsize=(15,5))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[4])
plt.xticks(rotation='vertical')
plt.xlabel('Area', fontsize=12)
plt.ylabel('Area harvest', fontsize=12)
plt.title('Area harvest of 30 countries', fontsize=18)
plt.show()

# %%
histt = data.Item
cnt_srs = histt.value_counts()
cnt_srs = cnt_srs.head(70)
plt.figure(figsize=(15,5))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[1])
plt.xticks(rotation='vertical')
plt.xlabel('Name', fontsize=12)
plt.ylabel('production', fontsize=12)
plt.title('Production of Crops', fontsize=18)
plt.show()

# %%
histt = data.Y1961
histtt = data.Y2014
cnt_srs = histt.value_counts()
cnt_srs1 = histtt.value_counts()
cnt_srs = cnt_srs.head(70)
cnt_srs1 = cnt_srs1.head(70)
plt.figure(figsize=(5,5))
sns.scatterplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[1])
sns.scatterplot(cnt_srs1.index, cnt_srs1.values, alpha=0.8, color=color[2])
plt.xticks(rotation='vertical')
plt.xlabel('Area', fontsize=12)
plt.ylabel('Area harvest', fontsize=12)
plt.title('Area harvest', fontsize=18)
plt.show()

# %%
# CORRELATION

def find_corr_for_all_columns():
    print("\ncorrelation coefficients for all numeric columns\n")
    print(data.corr(method='pearson'))
find_corr_for_all_columns()
# Out:
# correlation coefficients for all numeric columns
#
#               Area Code  Item Code  Element Code     Y1961     Y1962  \
# Area Code      1.000000  -0.006749     -0.003181 -0.056638 -0.056271
# Item Code     -0.006749   1.000000      0.006523  0.084040  0.078678
# Element Code  -0.003181   0.006523      1.000000  0.015091  0.013847
# Y1961         -0.056638   0.084040      0.015091  1.000000  0.998020
# Y1962         -0.056271   0.078678      0.013847  0.998020  1.000000
# Y1963         -0.055713   0.078331      0.015225  0.991389  0.995669
# Y1964         -0.056029   0.076542      0.015994  0.985368  0.990166
# Y1965         -0.056379   0.073696      0.018033  0.981884  0.988207
# Y1966         -0.056456   0.072410      0.019678  0.973568  0.981850
# Y1967         -0.057027   0.074677      0.021001  0.971746  0.981269
# Y1968         -0.056536   0.075372      0.022509  0.975565  0.984348
# Y1969         -0.055475   0.072831      0.023843  0.980324  0.987486
# ...

# %%
#CORRELATION

def corr_1961_and_2014():
    corr_coeff = data['Y1961'].corr(data['Y2014'])
    print("\ncorrelation coeff between Y1961 and Y2014 is ", corr_coeff)
    if (corr_coeff == 0):
        print("Y1961 and Y2014 are not related")
    elif (corr_coeff < 0.8 and corr_coeff > 0):
        print("Year 1961 and 2014 values are directly related")
    else:
        print("Year 1961 and 2014 values are Indirectly related") 
corr_1961_and_2014()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-32159865fdd0> in <module>
#      10     else:
#      11         print("Year 1961 and 2014 values are Indirectly related")
# ---> 12 corr_1961_and_2014()
#
# <ipython-input-1-32159865fdd0> in corr_1961_and_2014()
#       2
#       3 def corr_1961_and_2014():
# ----> 4     corr_coeff = data['Y1961'].corr(data['Y2014'])
#       5     print("\ncorrelation coeff between Y1961 and Y2014 is ", corr_coeff)
#       6     if (corr_coeff == 0):
#
# NameError: name 'data' is not defined
